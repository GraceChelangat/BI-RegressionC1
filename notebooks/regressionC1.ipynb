# %% [markdown]
# # BI-RegressionC1
# ### Member 1: Installation, Data Loading & Exploratory Data Analysis (EDA)
# ### Dataset: Retail Daily Sales
# ### Target Variable: daily_sales_revenue_kes

# %%
# !git clone https://github.com/GraceChelangat/BI-RegressionC1.git
# %cd BI-RegressionC1/notebooks
# Out:
# Cloning into 'BI-RegressionC1'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 44 (delta 20), reused 21 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 781.38 KiB | 4.16 MiB/s, done.
# Resolving deltas: 100% (20/20), done.
# /content/BI-RegressionC1/notebooks

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/retail_daily_sales.csv")

# %%
df.head()
# Out:
#    store_id store_format location_type delivery_available store_size_category  \
# 0         1  Supermarket        Street                 No              Medium
# 1         2  Hypermarket   Residential                Yes               Small
# 2         3        Kiosk          Mall                Yes              Medium
# 3         4  Convenience   Residential                 No              Medium
# 4         5  Supermarket          Mall                 No               Large
#
#    store_age_years  store_size_sqm  num_staff  promotions_active  \
# 0              3.9           130.4          3                  3
# 1              3.2           209.5          7                  1
# 2              2.6           272.2          7                  0
# 3              3.6           210.3          6                  1
# 4              4.5           402.8          9                  1
#
#    footfall_count  loyalty_program_members  online_order_count  \
# ...

# %%
df.shape
# Out:
# (900, 15)

# %%
df.columns.tolist()
# Out:
# ['store_id',
#  'store_format',
#  'location_type',
#  'delivery_available',
#  'store_size_category',
#  'store_age_years',
#  'store_size_sqm',
#  'num_staff',
#  'promotions_active',
#  'footfall_count',
#  'loyalty_program_members',
#  'online_order_count',
#  'avg_basket_size_kes',
#  'local_events_nearby',
#  'daily_sales_revenue_kes']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   store_id                 900 non-null    int64
#  1   store_format             900 non-null    object
#  2   location_type            900 non-null    object
#  3   delivery_available       900 non-null    object
#  4   store_size_category      900 non-null    object
#  5   store_age_years          900 non-null    float64
#  6   store_size_sqm           900 non-null    float64
#  7   num_staff                900 non-null    int64
#  8   promotions_active        900 non-null    int64
#  9   footfall_count           900 non-null    float64
#  10  loyalty_program_members  900 non-null    int64
#  11  online_order_count       336 non-null    float64
#  12  avg_basket_size_kes      857 non-null    float64
#  13  local_events_nearby      900 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# store_id                     0
# store_format                 0
# location_type                0
# delivery_available           0
# store_size_category          0
# store_age_years              0
# store_size_sqm               0
# num_staff                    0
# promotions_active            0
# footfall_count               0
# loyalty_program_members      0
# online_order_count         564
# avg_basket_size_kes         43
# local_events_nearby          0
# daily_sales_revenue_kes      0
# dtype: int64

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100

missing_percentage.sort_values(ascending=False)
# Out:
# online_order_count         62.666667
# avg_basket_size_kes         4.777778
# store_id                    0.000000
# delivery_available          0.000000
# store_size_category         0.000000
# store_format                0.000000
# location_type               0.000000
# store_size_sqm              0.000000
# store_age_years             0.000000
# num_staff                   0.000000
# promotions_active           0.000000
# loyalty_program_members     0.000000
# footfall_count              0.000000
# local_events_nearby         0.000000
# daily_sales_revenue_kes     0.000000
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# store_id                     int64
# store_format                object
# location_type               object
# delivery_available          object
# store_size_category         object
# store_age_years            float64
# store_size_sqm             float64
# num_staff                    int64
# promotions_active            int64
# footfall_count             float64
# loyalty_program_members      int64
# online_order_count         float64
# avg_basket_size_kes        float64
# local_events_nearby          int64
# daily_sales_revenue_kes    float64
# dtype: object

# %%
df.describe()
# Out:
#          store_id  store_age_years  store_size_sqm   num_staff  \
# count  900.000000       900.000000      900.000000  900.000000
# mean   450.500000         5.612111      220.273444    4.912222
# std    259.951919         3.831446      122.158525    2.945947
# min      1.000000         0.200000       25.000000    1.000000
# 25%    225.750000         2.775000      122.725000    3.000000
# 50%    450.500000         4.800000      194.000000    5.000000
# 75%    675.250000         7.700000      303.700000    7.000000
# max    900.000000        25.200000      755.300000   18.000000
#
#        promotions_active  footfall_count  loyalty_program_members  \
# count         900.000000      900.000000               900.000000
# mean            1.520000      179.574444                53.501111
# std             1.218435      105.056497                31.744513
# min             0.000000       14.000000                 4.000000
# ...

# %%
df["daily_sales_revenue_kes"].describe()
# Out:
# count    9.000000e+02
# mean     1.387285e+05
# std      1.021752e+05
# min      2.660600e+04
# 25%      8.336875e+04
# 50%      1.202575e+05
# 75%      1.666525e+05
# max      1.759621e+06
# Name: daily_sales_revenue_kes, dtype: float64

# %%
numeric_columns = df.select_dtypes(include=np.number).columns.tolist()

numeric_columns
# Out:
# ['store_id',
#  'store_age_years',
#  'store_size_sqm',
#  'num_staff',
#  'promotions_active',
#  'footfall_count',
#  'loyalty_program_members',
#  'online_order_count',
#  'avg_basket_size_kes',
#  'local_events_nearby',
#  'daily_sales_revenue_kes']

# %%
categorical_columns = df.select_dtypes(exclude="number")

categorical_columns
# Out:
#     store_format location_type delivery_available store_size_category
# 0    Supermarket        Street                 No              Medium
# 1    Hypermarket   Residential                Yes               Small
# 2          Kiosk          Mall                Yes              Medium
# 3    Convenience   Residential                 No              Medium
# 4    Supermarket          Mall                 No               Large
# ..           ...           ...                ...                 ...
# 895  Convenience   Residential                 No               Small
# 896  Supermarket        Street                Yes               Small
# 897  Hypermarket   Residential                 No              Medium
# 898  Convenience          Mall                 No              Medium
# 899  Convenience           CBD                 No               Large
#
# [900 rows x 4 columns]

# %%
for column in categorical_columns:
    print("\n", column)
    print(df[column].value_counts())
# Out:
#  store_format
# store_format
# Supermarket    314
# Convenience    274
# Kiosk          169
# Hypermarket    143
# Name: count, dtype: int64
#
#  location_type
# location_type
# Residential    265
# Street         221
# Mall           218
# CBD            196
# Name: count, dtype: int64
#
#  delivery_available
# delivery_available
# No     564
# Yes    336
# Name: count, dtype: int64
#
#  store_size_category
# store_size_category
# Medium    368
# Small     344
# Large     188
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))

sns.histplot(
    df["daily_sales_revenue_kes"],
    kde=True
)

plt.title("Distribution of Daily Sales Revenue")
plt.xlabel("Daily Sales Revenue (KES)")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(8, 4))

sns.boxplot(
    x=df["daily_sales_revenue_kes"]
)

plt.title("Boxplot of Daily Sales Revenue")
plt.xlabel("Daily Sales Revenue (KES)")

plt.show()

# %%
import os
os.getcwd()
# Out:
# '/content/BI-RegressionC1/notebooks'

# %%
import os

print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'regressionC1.ipynb']

# %%
df.shape
# Out:
# (900, 15)

# %% [markdown]
# # TRAIN / TEST SPLIT
# ### Member 2: Train and test split and feature selection

# %%
TARGET = "daily_sales_revenue_kes"

# Remove the target and store ID from the predictors
X = df.drop(columns=[TARGET, "store_id"])
y = df[TARGET]

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (900, 13)
# y shape: (900,)

# %%
#Dividing the target variable into quantile-based bins
y_bins = pd.qcut(y, q=5, labels=False, duplicates="drop")
print(y_bins.value_counts().sort_index())
# Out:
# daily_sales_revenue_kes
# 0    180
# 1    180
# 2    180
# 3    180
# 4    180
# Name: count, dtype: int64

# %%
#performing the train/test split
from sklearn.model_selection import train_test_split

RANDOM_STATE = 42

#Split the data into 80% training and 20% testing sets to prevent data leakage
# 80/20 keeps 80% for model development and 20% for unbiased final testing.
# Since the target is a highly right-skewed continuous revenue target—the quantile bins help preserve its range across the 80/20 split.
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=RANDOM_STATE,
    stratify=y_bins
    )
print("Training Set:", X_train.shape)
print("Testing Set:", X_test.shape)
print("Training target:", y_train.shape)
print("Testing target:", y_test.shape)
# Out:
# Training Set: (720, 13)
# Testing Set: (180, 13)
# Training target: (720,)
# Testing target: (180,)

# %%
split_summary = pd.DataFrame({
    "Training": y_train.describe(),
    "Testing": y_test.describe()
})
display(split_summary)
# Out:
#            Training        Testing
# count  7.200000e+02     180.000000
# mean   1.401950e+05  132862.755556
# std    1.086039e+05   70795.095440
# min    2.660600e+04   36759.000000
# 25%    8.332850e+04   84861.250000
# 50%    1.201110e+05  120422.500000
# 75%    1.664088e+05  167936.750000
# max    1.759621e+06  488268.000000

# %%
# Calculate key target statistics for both datasets
print("Training mean:", y_train.mean())
print("Testing mean:", y_test.mean())

print("Training median:", y_train.median())
print("Testing median:", y_test.median())

print("Training skewness:", y_train.skew())
print("Testing skewness:", y_test.skew())
# Out:
# Training mean: 140194.9625
# Testing mean: 132862.75555555554
# Training median: 120111.0
# Testing median: 120422.5
# Training skewness: 6.703885144356289
# Testing skewness: 1.603326965938511

# %%
# Feature selection
# 1. Correlation-based feature selection
# Calculated on training data only to prevent test-data leakage.
# Select numerical predictors from the training data
numeric_train = X_train.select_dtypes(include=np.number)

train_correlations = numeric_train.corrwith(y_train)

# Sort correlations by absolute strength
train_correlations = train_correlations.sort_values(
    key=lambda x: x.abs(),
    ascending=False
)

# Display the correlations
display(train_correlations)
# Out:
# store_size_sqm             0.277172
# footfall_count             0.247852
# loyalty_program_members    0.247331
# num_staff                  0.242412
# promotions_active          0.205190
# avg_basket_size_kes        0.184191
# online_order_count        -0.052141
# store_age_years           -0.049930
# local_events_nearby       -0.000787
# dtype: float64

# %%
#  bar chart of numerical feature correlations
plt.figure(figsize=(10, 6))

train_correlations.sort_values().plot(kind="barh")


plt.title("Training-Set Correlation with Daily Sales Revenue")
plt.xlabel("Pearson Correlation")
plt.ylabel("Feature")

plt.tight_layout()
plt.show()

# %%
# Preparing training data for mutual information analysis
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

# Identify numerical columns in the training predictors
numeric_features = X_train.select_dtypes(include=np.number).columns.tolist()

# Identify categorical columns in the training predictors
categorical_features = X_train.select_dtypes(exclude=np.number).columns.tolist()

# Create an encoder for categorical variables
mi_preprocessor = ColumnTransformer(
    transformers=[
        (
            "cat",
            OneHotEncoder(
                handle_unknown="ignore",
                sparse_output=False
            ),
            categorical_features
        ),
        (
            "num",
            # Impute missing numeric values so mutual_info_regression doesn't choke on NaN
            SimpleImputer(strategy="median"),
            numeric_features
        )
    ]
)

# Fit the encoder using training data only
X_train_encoded = mi_preprocessor.fit_transform(X_train)

# Get the resulting feature names
mi_feature_names = mi_preprocessor.get_feature_names_out()

# Convert the encoded data into a DataFrame
X_train_mi = pd.DataFrame(
    X_train_encoded,
    columns=mi_feature_names,
    index=X_train.index
)

# Display the shape
print("Encoded training data shape:", X_train_mi.shape)
# Out:
# Encoded training data shape: (720, 22)

# %%
#2. Feature selection based on mutual information
#Mutual Information detects broader/non-linear relationships.
from sklearn.feature_selection import mutual_info_regression

# Calculate mutual information using training data only
mi_scores = mutual_info_regression(
    X_train_mi,
    y_train,
    random_state=RANDOM_STATE
)

# Store the scores in a DataFrame
mi_results = pd.DataFrame({
    "feature": mi_feature_names,
    "mutual_information": mi_scores
})

# Sort features from highest to lowest score
mi_results = mi_results.sort_values(
    "mutual_information",
    ascending=False
)

# Display the strongest relationships
display(mi_results.head(15))
# Out:
#                             feature  mutual_information
# 17              num__footfall_count            0.126758
# 12   cat__store_size_category_Small            0.113890
# 18     num__loyalty_program_members            0.088333
# 14              num__store_size_sqm            0.085610
# 10   cat__store_size_category_Large            0.082893
# 15                   num__num_staff            0.052622
# 5           cat__location_type_Mall            0.046006
# 11  cat__store_size_category_Medium            0.034412
# 13             num__store_age_years            0.020217
# 1     cat__store_format_Hypermarket            0.018370
# 20         num__avg_basket_size_kes            0.017788
# 2           cat__store_format_Kiosk            0.017621
# 4            cat__location_type_CBD            0.016548
# 21         num__local_events_nearby            0.009777
# 16           num__promotions_active            0.004959

# %%
# Select the 15 strongest features
top_mi = mi_results.head(15).sort_values("mutual_information")

# Create the plot
plt.figure(figsize=(10, 7))

plt.barh(
    top_mi["feature"],
    top_mi["mutual_information"]
)

# Add labels
plt.title("Top Features by Mutual Information")
plt.xlabel("Mutual Information")
plt.ylabel("Feature")

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Confirm that store_id is not included in the predictors
print("store_id in predictors:", "store_id" in X_train.columns)
# Out:
# store_id in predictors: False

# %%
#Checking for highly correlated numerical predictors to reduce multicollinearity
# This helps avoid keeping features that provide almost duplicate information.

# Calculate correlations between numerical predictors using training data
predictor_corr = numeric_train.corr().abs()

# Keep only the upper triangle of the correlation matrix
upper_triangle = predictor_corr.where(
    np.triu(np.ones(predictor_corr.shape), k=1).astype(bool)
)

# Find predictor pairs with correlation above 0.80
high_corr_pairs = (
    upper_triangle
    .stack()
    .reset_index()
)

# Rename the columns
high_corr_pairs.columns = ["Feature 1", "Feature 2", "Absolute Correlation"]

# Keep only strong correlations
high_corr_pairs = high_corr_pairs[
    high_corr_pairs["Absolute Correlation"] > 0.80
]

# Sort from strongest to weakest
high_corr_pairs = high_corr_pairs.sort_values(
    "Absolute Correlation",
    ascending=False
)

# Display the results
display(high_corr_pairs)
# Out:
#          Feature 1                Feature 2  Absolute Correlation
# 26  footfall_count  loyalty_program_members              0.971674
# 8   store_size_sqm                num_staff              0.882135

# %%
# Dataset-specific decision: drop store_id because it is only an identifier.
# Keep the remaining predictors because they describe store characteristics
# or activities that may help predict daily sales revenue.


# Display the final predictors selected for model development
selected_features = X_train.columns.tolist()


print("Selected features:")
for feature in selected_features:
    print("-", feature)
print("Total number of selected features:", len(selected_features))
print("The target variable is still:", TARGET)
# Out:
# Selected features:
# - store_format
# - location_type
# - delivery_available
# - store_size_category
# - store_age_years
# - store_size_sqm
# - num_staff
# - promotions_active
# - footfall_count
# - loyalty_program_members
# - online_order_count
# - avg_basket_size_kes
# - local_events_nearby
# Total number of selected features: 13
# The target variable is still: daily_sales_revenue_kes

# %% [markdown]
# <h1 style="color:black; font-size:28px;"><b>PREPROCESSING PIPELINE</b></h1>
#
# <h2 style="color:black; font-size:22px;"><b>Member 3: Encoding, Imputation, Scaling and Target Transformation</b></h2>

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
# Check whether online_order_count's missingness is linked to delivery_available
pd.crosstab(X_train["delivery_available"], X_train["online_order_count"].isna())
# Out:
# online_order_count  False  True
# delivery_available
# No                      0    446
# Yes                   274      0

# %% [markdown]
# ### Structural Missingness
#
# `online_order_count` is missing when `delivery_available` is **"No"**.
#
# This makes sense because a store that does not offer delivery will not have online orders. So the value is not missing because of an error it is simply **not applicable**.
#
# This is called **structural missingness**.

# %%
# Check whether avg_basket_size_kes missingness follows any pattern
display(pd.crosstab(X_train["delivery_available"], X_train["avg_basket_size_kes"].isna()))
display(pd.crosstab(X_train["store_format"], X_train["avg_basket_size_kes"].isna()))
display(pd.crosstab(X_train["store_size_category"], X_train["avg_basket_size_kes"].isna()))
# Out:
# avg_basket_size_kes  False  True
# delivery_available
# No                     425     21
# Yes                    260     14
# avg_basket_size_kes  False  True
# store_format
# Convenience            198     11
# Hypermarket            111      1
# Kiosk                  133      8
# Supermarket            243     15
# avg_basket_size_kes  False  True
# store_size_category
# Large                  135      9
# Medium                 290     16
# Small                  260     10

# %% [markdown]
# ### Random Missingness
#
# About **5%** of the `avg_basket_size_kes` values are missing.
#
# The missing values are not related to other variables such as delivery availability, store format or store size. There is no clear reason for the missing values.
#
# Therefore this is considered **random missingness**.

# %%
structural_missing_feature = ["online_order_count"]   # missing when delivery is "No"
random_missing_features    = ["avg_basket_size_kes"]   # missing with no clear pattern
other_numeric_features = [
    "store_age_years", "store_size_sqm", "num_staff",
    "promotions_active", "footfall_count",
    "loyalty_program_members", "local_events_nearby",
]
categorical_features = [
    "store_format", "location_type",
    "delivery_available", "store_size_category",
]

# %%
preprocessor = ColumnTransformer(
    transformers=[
        # Structural missingness -> impute with 0 (no delivery = 0 online orders)
        ("structural_num", Pipeline([
            ("impute_zero", SimpleImputer(strategy="constant", fill_value=0)),
            ("scale", StandardScaler()),
        ]), structural_missing_feature),

        # Random missingness -> impute with median
        ("random_num", Pipeline([
            ("impute_median", SimpleImputer(strategy="median")),
            ("scale", StandardScaler()),
        ]), random_missing_features),

        # Complete numeric columns -> scale only
        ("num", Pipeline([
            ("impute_median", SimpleImputer(strategy="median")),
            ("scale", StandardScaler()),
        ]), other_numeric_features),

        # Categorical columns
        ("cat", OneHotEncoder(handle_unknown="ignore", drop="first"),
         categorical_features),
    ]
)

# %%
X_train_processed = preprocessor.fit_transform(X_train)
X_test_processed  = preprocessor.transform(X_test)

print("X_train_processed shape:", X_train_processed.shape)
print("X_test_processed shape:", X_test_processed.shape)
print("Any NaNs left in train?", np.isnan(X_train_processed).any())
print("Any NaNs left in test?", np.isnan(X_test_processed).any())
# Out:
# X_train_processed shape: (720, 18)
# X_test_processed shape: (180, 18)
# Any NaNs left in train? False
# Any NaNs left in test? False

# %%
feature_names = preprocessor.get_feature_names_out()
list(feature_names)
# Out:
# ['structural_num__online_order_count',
#  'random_num__avg_basket_size_kes',
#  'num__store_age_years',
#  'num__store_size_sqm',
#  'num__num_staff',
#  'num__promotions_active',
#  'num__footfall_count',
#  'num__loyalty_program_members',
#  'num__local_events_nearby',
#  'cat__store_format_Hypermarket',
#  'cat__store_format_Kiosk',
#  'cat__store_format_Supermarket',
#  'cat__location_type_Mall',
#  'cat__location_type_Residential',
#  'cat__location_type_Street',
#  'cat__delivery_available_Yes',
#  'cat__store_size_category_Medium',
#  'cat__store_size_category_Small']

# %% [markdown]
# ### Target Transformation
#
# `daily_sales_revenue_kes` is always positive and has a strong right-skew (skewness ≈ **6.70**).
#
# A `log1p` transformation is used to reduce the skew. After transformation the skewness decreases to about **0.18** which is much closer to a normal distribution.
#
# `log1p` is used instead of Box-Cox because it is simpler and does not require estimating a λ parameter.
#
# The model will work with the **log-transformed values**. After making predictions `expm1` is used to convert them back to **KES** for the final evaluation.

# %%
y_train_log = np.log1p(y_train)
y_test_log  = np.log1p(y_test)

print("Skew before:", y_train.skew(), "| after log1p:", y_train_log.skew())
# Out:
# Skew before: 6.703885144356289 | after log1p: 0.18174574740997312

# %%
recovered = np.expm1(y_train_log)
print("Max reconstruction error:", np.max(np.abs(recovered.values - y_train.values)))
# Out:
# Max reconstruction error: 6.984919309616089e-10

# %% [markdown]
# ### End of Member 3's Section
#
# The data is now ready for the modeling stage.
#
# - `X_train_processed` and `X_test_processed` — the features are cleaned and prepared.
# - `y_train_log` and `y_test_log` — the target values are in log form.
# - `preprocessor`- the preprocessing steps can be reused on new data.
#
# **Important:** After making predictions use `np.expm1()` to change the predictions back to **KES** before checking the model's performance.

# %% [markdown]
# MEMBER 4

# %% [markdown]
# Model Training and Cross-Validation

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

models = {
    "Linear Regression": LinearRegression(),
    "Ridge": Ridge(random_state=RANDOM_STATE),
    "Lasso": Lasso(random_state=RANDOM_STATE, max_iter=5000),
    "ElasticNet": ElasticNet(random_state=RANDOM_STATE, max_iter=5000),
    "Decision Tree": DecisionTreeRegressor(random_state=RANDOM_STATE, max_depth=6),
    "Random Forest": RandomForestRegressor(random_state=RANDOM_STATE, n_estimators=200, max_depth=8),
    "Gradient Boosting": GradientBoostingRegressor(random_state=RANDOM_STATE, n_estimators=200, max_depth=3),
}

kfold = KFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)
cv_results = {}

print("Note: Lower RMSE is better (log scale).")
for name, model in models.items():
    pipeline = Pipeline(steps=[("preprocessor", preprocessor), ("model", model)])
    scores = cross_val_score(pipeline, X_train, y_train_log, cv=kfold,
                              scoring="neg_root_mean_squared_error", n_jobs=-1)
    cv_results[name] = -scores
    print(f"{name:20s} RMSE (log scale): {-scores.mean():.4f}  (+/- {scores.std():.4f})")
# Out:
# Note: Lower RMSE is better (log scale).
# Linear Regression    RMSE (log scale): 0.3280  (+/- 0.0512)
# Ridge                RMSE (log scale): 0.3279  (+/- 0.0510)
# Lasso                RMSE (log scale): 0.5626  (+/- 0.0237)
# ElasticNet           RMSE (log scale): 0.5626  (+/- 0.0237)
# Decision Tree        RMSE (log scale): 0.4646  (+/- 0.0426)
# Random Forest        RMSE (log scale): 0.3717  (+/- 0.0482)
# Gradient Boosting    RMSE (log scale): 0.3408  (+/- 0.0482)

# %%
cv_results_df = pd.DataFrame(cv_results)
plt.figure(figsize=(10, 5))
sns.boxplot(data=cv_results_df, color="#4F6EA4")
plt.ylabel("Cross-Validated RMSE (log scale)")
plt.title("5-Fold Cross-Validation: RMSE Distribution by Model")
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# END OF MEMBER 4

# %% [markdown]
# # MEMBER 5
# ### Diagnostics, Test Evaluation & Model Selection

# %% [markdown]
# ## Diagnostic Exploratory Data Analysis (Model Diagnostics)
#
# Diagnostic EDA verifies that the assumptions underlying the regression model are satisfied. Confirming these assumptions hold ensures the statistical tests used in the model are valid, reducing the risk of drawing incorrect or misleading conclusions.
#
# We use a `LinearRegression` pipeline (built on Member 3's `preprocessor`) for this stage, because classical regression diagnostics:residual structure, homoscedasticity, autocorrelation are most directly interpretable for a linear model. It is fit once on the full training set (not cross-validated) purely for diagnostic purposes.
#
# ### Test of Linearity - Residuals vs. Fitted Values
#
# For the model to pass the test of linearity, there should be no pattern in the distribution of residuals; they should be randomly scattered around the 0.0 line.
#
# ### Test of Normality of the Errors - Q-Q Plot
#
# A Q-Q plot compares the quantiles of the residuals against a normal distribution. If the points show substantial departures from the diagonal line, the normality assumption may not be satisfied.

# %%
linear_pipeline = Pipeline(steps=[("preprocessor", preprocessor), ("model", LinearRegression())])
linear_pipeline.fit(X_train, y_train_log)

fitted_values = linear_pipeline.predict(X_train)
residuals = y_train_log.values - fitted_values

# %%
from scipy import stats

fig, axes = plt.subplots(1, 2, figsize=(13, 5))

axes[0].scatter(fitted_values, residuals, alpha=0.3, s=15, color="#4F6EA4")
axes[0].axhline(0, color="#1D1D1D", linestyle="--", linewidth=1)
axes[0].set_xlabel("Fitted values (log scale)")
axes[0].set_ylabel("Residuals")
axes[0].set_title("Residuals vs. Fitted Values\n(checks linearity and homoscedasticity)")

stats.probplot(residuals, dist="norm", plot=axes[1])
axes[1].set_title("Q-Q Plot of Residuals\n(checks normality of the distribution of errors)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Test of Homoscedasticity - Breusch-Pagan Test
#
# A formal complement to the visual check above.
#
# - Null hypothesis (H₀): the error variance is homoscedastic (equal variance).
# - Alternative hypothesis (H₁): the error variance is heteroscedastic (non-constant variance).
# - p-value ≥ 0.05: fail to reject H₀ → no evidence of heteroscedasticity → model passes.
# - p-value < 0.05: reject H₀ → evidence of heteroscedasticity → model fails.

# %%
import statsmodels.api as sm
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.stats.stattools import durbin_watson

X_train_transformed = preprocessor.transform(X_train)
X_train_with_const = sm.add_constant(X_train_transformed)

bp_test = het_breuschpagan(residuals, X_train_with_const)
bp_labels = ["Breusch-Pagan LM Statistic", "Breusch-Pagan LM p-value", "F-Statistic", "F p-value"]
for label, value in zip(bp_labels, bp_test):
    print(f"{label}: {value:.4f}")
# Out:
# Breusch-Pagan LM Statistic: 10.7005
# Breusch-Pagan LM p-value: 0.9066
# F-Statistic: 0.5875
# F p-value: 0.9099

# %% [markdown]
# ### Test of Independence of Errors (Autocorrelation) - Durbin-Watson Test
#
# `0 ≤ DW ≤ 4`, where `DW ≈ 2` suggests little/no autocorrelation, values toward 0 indicate positive autocorrelation, and values toward 4 indicate negative autocorrelation. This dataset is cross-sectional (not a time series), so we expect a value close to 2.

# %%
dw_stat = durbin_watson(residuals)
print(f"Durbin-Watson statistic: {dw_stat:.4f}")
# Out:
# Durbin-Watson statistic: 1.9712

# %% [markdown]
# ### Test of Multicollinearity - Variance Inflation Factor (VIF)
#
# VIF measures how much the variance of an estimated coefficient is inflated because a predictor is linearly related to other predictors. VIF > 5 is worth investigating; VIF > 10 is a strong indication of multicollinearity. VIF requires a fully numeric, non-missing matrix, so we median-impute the numeric features purely for this diagnostic, this is not the imputation used inside the final pipeline.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

numeric_feature_names = structural_missing_feature + random_missing_features + other_numeric_features
numeric_train_imputed = X_train[numeric_feature_names].copy()
for column in numeric_train_imputed.columns:
    numeric_train_imputed[column] = numeric_train_imputed[column].fillna(numeric_train_imputed[column].median())

vif_recheck = pd.DataFrame()
vif_recheck["feature"] = numeric_feature_names
vif_recheck["VIF"] = [
    variance_inflation_factor(numeric_train_imputed.values, i)
    for i in range(numeric_train_imputed.shape[1])
]
vif_recheck.sort_values("VIF", ascending=False).round(2)
# Out:
#                    feature    VIF
# 6           footfall_count  18.04
# 7  loyalty_program_members  18.02
# 3           store_size_sqm   4.54
# 4                num_staff   4.54
# 8      local_events_nearby   1.02
# 0       online_order_count   1.02
# 1      avg_basket_size_kes   1.02
# 5        promotions_active   1.01
# 2          store_age_years   1.01

# %% [markdown]
# ### Test of Outliers - Cook's Distance
#
# Cook's distance measures how much a single observation influences the entire regression model: if removed and the model refit, how much would predictions change? It is high when an observation is both an outlier in `y` (large residual) and high-leverage in `X` (unusual predictor values)it's the combination that matters.
#
# **Threshold:** a common rule of thumb is `4/n`. Points above it deserve inspection, not automatic removal, they may be data entry errors, genuinely unusual but valid cases, or simply high-revenue stores.

# %%
influence = sm.OLS(y_train_log.values, X_train_with_const).fit()
cooks_d = influence.get_influence().cooks_distance[0]

influential_threshold = 4 / len(y_train_log)
n_influential = (cooks_d > influential_threshold).sum()

plt.figure(figsize=(11, 4.5))
plt.stem(cooks_d, markerfmt=",")
plt.axhline(influential_threshold, color="red", linestyle="--",
            label=f"Threshold = 4/n = {influential_threshold:.4f}")
plt.xlabel("Observation index")
plt.ylabel("Cook's Distance")
plt.title(f"Cook's Distance ({n_influential} observations exceed threshold)")
plt.legend()
plt.tight_layout()
plt.show()

print(f"Number of influential observations flagged: {n_influential} out of {len(y_train_log)}")
# Out:
# Number of influential observations flagged: 23 out of 720

# %%
influential_idx = np.where(cooks_d > influential_threshold)[0]

influential_summary = pd.DataFrame({
    "Observation Index in Dataset": influential_idx,
    "Cooks Distance": cooks_d[influential_idx]
}).sort_values("Cooks Distance", ascending=False).reset_index(drop=True)

influential_summary
# Out:
#     Observation Index in Dataset  Cooks Distance
# 0                            319        0.069815
# 1                            300        0.066123
# 2                            107        0.054110
# 3                            350        0.045754
# 4                            257        0.042244
# 5                            140        0.028818
# 6                            636        0.027115
# 7                             21        0.025266
# 8                            482        0.011884
# 9                            165        0.009712
# 10                           439        0.008554
# 11                           237        0.008342
# 12                           316        0.008190
# 13                           239        0.008136
# 14                           100        0.007727
# 15                           256        0.007593
# 16                           539        0.007230
# 17                           210        0.007212
# ...

# %% [markdown]
# ## Evaluating the Performance of Several Models
#
# Each of Member 4's candidate models is fit on the full training set and evaluated once on the held-out test set. Metrics are reported in the **original KES scale** (after inverting `log1p` with `np.expm1`), since stakeholders reason in KES, not log-revenue units.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def adjusted_r2(r2, n, p):
    return 1 - (1 - r2) * (n - 1) / (n - p - 1)

def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

evaluation_results = []

for name, model in models.items():
    pipeline = Pipeline(steps=[("preprocessor", preprocessor), ("model", model)])
    pipeline.fit(X_train, y_train_log)

    y_pred_log = pipeline.predict(X_test)
    y_pred = np.expm1(y_pred_log)
    y_true = y_test.values

    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_pred)
    adj_r2 = adjusted_r2(r2, len(y_true), X_test.shape[1])
    mape = mean_absolute_percentage_error(y_true, y_pred)

    evaluation_results.append({
        "Model": name, "MAE (KES)": mae, "MSE": mse, "RMSE (KES)": rmse,
        "R2": r2, "Adjusted R2": adj_r2, "MAPE (%)": mape
    })

evaluation_df = pd.DataFrame(evaluation_results).sort_values("RMSE (KES)")
evaluation_df.style.format({
    "MAE (KES)": "{:,.0f}", "MSE": "{:,.0f}", "RMSE (KES)": "{:,.0f}",
    "R2": "{:.3f}", "Adjusted R2": "{:.3f}", "MAPE (%)": "{:.2f}"
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_a7aaf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7aaf_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a7aaf_level0_col1" class="col_heading level0 col1" >MAE (KES)</th>
#       <th id="T_a7aaf_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a7aaf_level0_col3" class="col_heading level0 col3" >RMSE (KES)</th>
#       <th id="T_a7aaf_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a7aaf_level0_col5" class="col_heading level0 col5" >Adjusted R2</th>
#       <th id="T_a7aaf_level0_col6" class="col_heading level0 col6" >MAPE (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7aaf_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a7aaf_row0_col0" class="data row0 col0" >Ridge</td>
#       <td id="T_a7aaf_row0_col1" class="data row0 col1" >28,676</td>
# ...

# %% [markdown]
# ### Model Selection
#
# Ranking by test-set RMSE, the linear-family models (Ridge, Linear Regression) are the strongest performers at default settings, followed by Gradient Boosting and Random Forest. Decision Tree trails, and Lasso / ElasticNet underperform at their default `alpha=1.0`the regularization penalty is too strong for standardized features and shrinks most coefficients toward zero.
#
# This is expected at default hyperparameters and is exactly why Member 6's hyperparameter tuning searches a range of `alpha` values for Ridge, Lasso, and ElasticNet, plus a wider grid for Gradient Boosting: a properly tuned regularized model or boosted tree can outperform the untuned baselines above. The diagnostics in this section (no strong heteroscedasticity, no meaningful autocorrelation, acceptable VIF, and a small number of flagged high-revenue outliers) confirm the linear model's assumptions are reasonably well satisfied, which supports carrying linear-family models forward into tuning rather than discarding them.

# %% [markdown]
# ### End of Member 5

# %% [markdown]
# # MEMBER 6
# ### Hyperparameter Tuning, Explainability & Model Persistence

# %% [markdown]
# ### Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import Ridge, Lasso, ElasticNet

# Placeholder model -- GridSearchCV swaps it out via param_grid below
tuning_pipeline = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("model", Ridge())
])

param_grid = [
    {
        "model": [Ridge(random_state=RANDOM_STATE)],
        "model__alpha": [0.001, 0.01, 0.1, 1.0, 10.0, 100.0]
    },
    {
        "model": [Lasso(random_state=RANDOM_STATE, max_iter=20000)],
        "model__alpha": [1e-4, 1e-3, 1e-2, 1e-1, 1.0]
    },
    {
        "model": [ElasticNet(random_state=RANDOM_STATE, max_iter=20000)],
        "model__alpha": [1e-4, 1e-3, 1e-2, 1e-1, 1.0],
        "model__l1_ratio": [0.2, 0.5, 0.8]
    },
    {
        "model": [GradientBoostingRegressor(random_state=RANDOM_STATE)],
        "model__n_estimators": [100, 200, 300],
        "model__max_depth": [2, 3, 4],
        "model__learning_rate": [0.03, 0.1, 0.2],
        "model__subsample": [0.8, 1.0]
    }
]

grid_search = GridSearchCV(
    estimator=tuning_pipeline,
    param_grid=param_grid,
    cv=kfold,
    scoring="neg_root_mean_squared_error",
    n_jobs=-1,
    verbose=0
)

grid_search.fit(X_train, y_train_log)

print(f"Best tuned model: {grid_search.best_estimator_.named_steps['model']}")
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best CV RMSE (log scale): {-grid_search.best_score_:.4f}")
# Out:
# Best tuned model: Lasso(alpha=0.001, max_iter=20000, random_state=42)
# Best parameters: {'model': Lasso(max_iter=20000, random_state=42), 'model__alpha': 0.001}
# Best CV RMSE (log scale): 0.3278

# %% [markdown]
# ### Quick Test-Set Check on the Winning Model

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

best_model = grid_search.best_estimator_
best_regressor = best_model.named_steps["model"]
best_model_name = best_regressor.__class__.__name__

y_pred_log = best_model.predict(X_test)
y_pred_kes = np.expm1(y_pred_log)
y_true_kes = y_test.values

rmse_kes = np.sqrt(mean_squared_error(y_true_kes, y_pred_kes))
mae_kes = mean_absolute_error(y_true_kes, y_pred_kes)
r2 = r2_score(y_true_kes, y_pred_kes)

print(f"Best tuned model: {best_model_name}")
print(f"Best params: {grid_search.best_params_}")
print(f"Best CV RMSE (log scale): {-grid_search.best_score_:.4f}")
print(f"Test MAE: {mae_kes:,.0f} KES | Test RMSE: {rmse_kes:,.0f} KES | Test R2: {r2:.3f}")

# Handed off to Member 5 for the full diagnostics and test-set evaluation write-up.
# Out:
# Best tuned model: Lasso
# Best params: {'model': Lasso(max_iter=20000, random_state=42), 'model__alpha': 0.001}
# Best CV RMSE (log scale): 0.3278
# Test MAE: 28,603 KES | Test RMSE: 40,848 KES | Test R2: 0.665

# %% [markdown]
# ## Explainability
#
# ### Coefficient Interpretation
#
# Because numeric features are standardized inside `preprocessor`, a linear model's coefficients are directly comparable in magnitude: a larger absolute coefficient indicates a stronger association with log-revenue, holding other features constant. If the winning model is tree-based instead, it has no `.coef_`, so we fall back to SHAP, PDP, and permutation importance below.

# %%
feature_names_out = best_model.named_steps["preprocessor"].get_feature_names_out()

if hasattr(best_regressor, "coef_"):
    coefs_df = pd.DataFrame({
        "feature": feature_names_out,
        "coefficient": best_regressor.coef_
    }).sort_values("coefficient", key=abs, ascending=False)

    plt.figure(figsize=(9, 6))
    top_coefs = coefs_df.head(15)
    sns.barplot(data=top_coefs, y="feature", x="coefficient", color="#4F6EA4")
    plt.title(f"Top 15 Standardized Coefficients ({best_model_name})")
    plt.tight_layout()
    plt.show()
else:
    print(f"{best_model_name} does not provide .coef_.")
    print("Use permutation importance / SHAP / Partial Dependence Plots for explainability instead.")

# %% [markdown]
# ### SHapley Additive exPlanations (SHAP) Values
#
# SHAP explains individual predictions: for a given store-day, how much did each feature push the prediction up or down relative to the average prediction? It is built on Shapley values from cooperative game theory (Shapley, 1952), treating features as "players" sharing credit for the model's output.
#
# - **Additive**: the SHAP values for one observation sum exactly to (prediction − baseline).
# - **Local**: each observation gets its own explanation, not just one global summary.
# - **Model-agnostic in principle**, though tree models use the faster `TreeExplainer` and linear models use `LinearExplainer`.

# %%
# %pip install shap -q

# %%
import shap

X_test_sample = X_test.iloc[:500].copy()
X_test_transformed = best_model.named_steps["preprocessor"].transform(X_test_sample)

if "Forest" in best_model_name or "GradientBoosting" in best_model_name or "Tree" in best_model_name:
    explainer = shap.TreeExplainer(best_regressor)
    shap_values = explainer.shap_values(X_test_transformed)

    shap.summary_plot(shap_values, X_test_transformed, feature_names=feature_names_out, show=False)
    plt.title(f"SHAP Summary ({best_model_name})")
    plt.tight_layout()
    plt.show()

elif hasattr(best_regressor, "coef_"):
    masker = shap.maskers.Independent(X_test_transformed, max_samples=300)
    explainer = shap.LinearExplainer(best_regressor, masker=masker)
    shap_values = explainer(X_test_transformed)

    shap.summary_plot(shap_values.values, X_test_transformed, feature_names=feature_names_out, show=False)
    plt.title(f"SHAP Summary ({best_model_name})")
    plt.tight_layout()
    plt.show()

else:
    print(f"SHAP explainer not configured for model type: {best_model_name}")

# %% [markdown]
# ### Partial Dependence Plots (PDP)
#
# A PDP shows how the model's average prediction changes as one feature varies, holding all other features at their observed values and averaging across the dataset. We use `footfall_count` and `store_size_sqm`, the two numeric predictors with the strongest raw correlation to `daily_sales_revenue_kes`.
#
# PDP is global and averaged (one curve for the whole dataset, unlike SHAP's per-observation view), and can mislead when features are correlated, since "holding everything else fixed" can generate unrealistic combinations.

# %%
from sklearn.inspection import PartialDependenceDisplay

features_to_plot = ["footfall_count", "store_size_sqm"]

fig, ax = plt.subplots(figsize=(11, 4.5))
PartialDependenceDisplay.from_estimator(best_model, X_train, features=features_to_plot, ax=ax)
plt.suptitle(f"Partial Dependence ({best_model_name})")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Permutation Feature Importance
#
# Shuffle one feature's values (breaking its link to the target), re-score the model, and measure how much performance drops. A larger drop means the model relied more heavily on that feature. This works for any model type, not just tree-based ones, and is evaluated here on the held-out test set.

# %%
from sklearn.inspection import permutation_importance

perm_result = permutation_importance(
    best_model,
    X_test,
    y_test_log,
    n_repeats=10,
    random_state=RANDOM_STATE,
    scoring="neg_root_mean_squared_error",
    n_jobs=-1
)

perm_importance_df = pd.DataFrame({
    "feature": X_test.columns,
    "importance_mean": perm_result.importances_mean,
    "importance_std": perm_result.importances_std,
}).sort_values("importance_mean", ascending=False)

plt.figure(figsize=(9, 6))
sns.barplot(
    data=perm_importance_df,
    y="feature",
    x="importance_mean",
    color="#4F6EA4",
    xerr=perm_importance_df["importance_std"]
)
plt.title(f"Permutation Feature Importance ({best_model_name}, test set)")
plt.xlabel("Mean decrease in RMSE score when feature is shuffled")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model Persistence
#
# We persist the **entire fitted pipeline** (preprocessing + model) as a single object. Saving the model alone, without the exact fitted encoders/imputers/scaler, is a common error: new data at inference time must pass through identical preprocessing, and saving the steps separately risks a mismatch between training-time and inference-time transformations.

# %%
import joblib
import os
from datetime import datetime

final_pipeline = grid_search.best_estimator_

# Refit on the full training data to be explicit (GridSearchCV already does this by default via refit=True)
final_pipeline.fit(X_train, y_train_log)

model_dir = "./model"
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

model_name = final_pipeline.named_steps["model"].__class__.__name__
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
model_filename = f"{timestamp}_{model_name}_regressor_for_retail_sales.joblib".lower()
model_path = os.path.normpath(os.path.join(model_dir, model_filename))

joblib.dump(final_pipeline, model_path)
print("Selected model:", model_name)
print(f"Best pipeline (preprocessing + model) saved to: {model_path}")
# Out:
# Selected model: Lasso
# Best pipeline (preprocessing + model) saved to: model/20260914_101049_lasso_regressor_for_retail_sales.joblib

# %%
# Demonstrate loading the fitted pipeline and predicting on a new, unseen store
loaded_pipeline = joblib.load(model_path)

new_store = pd.DataFrame([{
    "store_format": "Supermarket",
    "location_type": "Mall",
    "delivery_available": "Yes",
    "store_size_category": "Medium",
    "store_age_years": 5.0,
    "store_size_sqm": 450.0,
    "num_staff": 12,
    "promotions_active": 1,
    "footfall_count": 800.0,
    "loyalty_program_members": 150,
    "online_order_count": 40.0,
    "avg_basket_size_kes": 1200.0,
    "local_events_nearby": 0,
}])

# The pipeline was trained on log1p(daily_sales_revenue_kes), so predictions come out
# on the log scale -- np.expm1 inverts this back to KES.
predicted_log_revenue = loaded_pipeline.predict(new_store)
predicted_revenue = np.expm1(predicted_log_revenue)[0]

print(f"Predicted daily sales revenue for new store: {predicted_revenue:,.0f} KES")
# Out:
# Predicted daily sales revenue for new store: 636,876 KES

# %%
# Second check: confirm the pipeline does not error when online_order_count is NaN
# for a store with delivery_available == "No" (the structural-missingness case Member 3 identified)
new_store_no_delivery = pd.DataFrame([{
    "store_format": "Kiosk",
    "location_type": "Residential",
    "delivery_available": "No",
    "store_size_category": "Small",
    "store_age_years": 2.5,
    "store_size_sqm": 60.0,
    "num_staff": 3,
    "promotions_active": 0,
    "footfall_count": 250.0,
    "loyalty_program_members": 20,
    "online_order_count": np.nan,   # structurally missing: no delivery -> no online orders
    "avg_basket_size_kes": 450.0,
    "local_events_nearby": 0,
}])

predicted_log_revenue_nd = loaded_pipeline.predict(new_store_no_delivery)
predicted_revenue_nd = np.expm1(predicted_log_revenue_nd)[0]

print("Prediction succeeded without error for a non-delivery store with NaN online_order_count.")
print(f"Predicted daily sales revenue: {predicted_revenue_nd:,.0f} KES")
# Out:
# Prediction succeeded without error for a non-delivery store with NaN online_order_count.
# Predicted daily sales revenue: 47,867 KES
